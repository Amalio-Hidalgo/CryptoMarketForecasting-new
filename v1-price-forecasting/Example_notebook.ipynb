# %% [markdown]
# # Cryptocurrency Price Action Analysis
#
# This notebook demonstrates different approaches to cryptocurrency price prediction:
# 1. Pandas with local processing
# 2. Pandas with Dask distribution
# 3. Full Dask implementation

# %%
# Imports
import matplotlib
import matplotlib.pyplot as plt
import dask.dataframe as dd
import My_API_Wraps
import My_FE_Wraps
import My_FS_Wraps
from dask.distributed import Client, LocalCluster
import xgboost
from sklearn.metrics import r2_score
import pandas as pd
import datetime as dt
import numpy as np
from xgboost import dask as dxgb
import os
import cupy as cp
import optuna
import My_ML_Wraps
import warnings
import coiled
import My_Utilities
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
# Coiled Cluster Connecting to my AWS Account
cluster = coiled.Cluster(
    # n_workers= 3, # 1 to 3 workers
    # worker_memory="32GiB",
    region="eu-west-3",
    shutdown_on_close=True
)
client = cluster.get_client()
client
# Out:
# [2025-03-02 00:43:09,629][INFO    ][coiled] Fetching latest package priorities...
# [2025-03-02 00:43:09,632][INFO    ][coiled.package_sync] Resolving your local myenvironment Python environment...
# [2025-03-02 00:43:10,360][INFO    ][coiled.package_sync] Scanning 146 conda packages...
# [2025-03-02 00:43:10,370][INFO    ][coiled.package_sync] Scanning 171 python packages...
# [2025-03-02 00:43:11,531][INFO    ][coiled] Running pip check...
# [2025-03-02 00:43:12,608][INFO    ][coiled] Validating environment...
# [2025-03-02 00:43:16,894][INFO    ][coiled] Creating wheel for ~\AppData\Roaming\Python\Python312\site-packages\win32\lib...
# [2025-03-02 00:43:17,111][INFO    ][coiled] Creating wheel for ~\OneDrive\Desktop\Programming\new_programming...
# [2025-03-02 00:43:17,296][INFO    ][coiled] Creating wheel for ~\AppData\Roaming\Python\Python312\site-packages\pythonwin...
# [2025-03-02 00:43:17,668][INFO    ][coiled] Creating wheel for ~\AppData\Roaming\Python\Python312\site-packages\win32...
# [2025-03-02 00:43:18,117][WARNING ][coiled.package_sync] Package - libwinpthread, libwinpthread has no install candidate for Python 3.12 linux-64 on conda-forge
# [2025-03-02 00:43:18,118][WARNING ][coiled.package_sync] Package - dask-xgboost, Pip check had the following issues that need resolving:
# dask-xgboost 0.2.0 has requirement xgboost<=0.90, but you have xgboost 2.1.3.
# [2025-03-02 00:43:18,119][INFO    ][coiled] Uploading coiled_local_lib...
# [2025-03-02 00:43:19,368][INFO    ][coiled] Uploading coiled_local_new_programming...
# [2025-03-02 00:43:20,831][INFO    ][coiled] Uploading coiled_local_pythonwin...
# [2025-03-02 00:43:22,312][INFO    ][coiled] Uploading coiled_local_win32...
# [2025-03-02 00:43:23,807][INFO    ][coiled] Requesting package sync build...
# [2025-03-02 00:43:24,909][WARNING ][coiled] Using adaptive scaling with default range of `[4, 20]`. To manually control the size of your cluster, use n_workers=.
#
# [2025-03-02 00:43:24,912][INFO    ][coiled] Creating Cluster (name: amalio-hidalgo-7d00f45a, https://cloud.coiled.io/clusters/782559?account=amalio-hidalgo ). This usually takes 1-2 minutes...
# 2025-03-02 00:44:17,625 - distributed.deploy.adaptive_core - INFO - Adaptive scaling started: minimum=4 maximum=20
# <Client: 'tls://10.0.3.133:8786' processes=0 threads=0, memory=0 B>

# %%
# CPU optimized cluster for my CPU 
cluster = LocalCluster(
            n_workers=4,
            threads_per_worker=5,
            processes=True,
            dashboard_address=':8787',
            resources = {'GPU':2}
        )
client = Client(cluster)
client

# %%
# Work in progress-GPU optimized cluster with CUDA
# Notes:Windows doesn't support dask.distributed.LocalCudaCluster
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
cp.cuda.set_allocator(cp.cuda.MemoryPool().malloc)

cluster = LocalCluster(
    n_workers=1,              # Single worker for GPU
    processes=False,          # Thread-based
    threads_per_worker=32,    # Maximum threads for i7-13700H
    # memory_limit='22GB',      # 75% of system RAM
    dashboard_address=':8788',
    resources={'GPU': 1}
)
client = Client(cluster)
client

# %%
# Use to close client and cluster when done with Dask computations
client.close()
cluster.close()

# %%
# Key function parameters 
# Notes: 
# If timeframe=1, periods are 5minute intervals, else hourly
# Max timeframe=89, after lose hourly granularity
# For timeframe=1, setting periods higher than 3 will result in inusfficient partition sizes for feature extraction
periods= 4
timeframe= 89
top_coins= 2
api_key= "CG-r57ENE22zzPUiLmjnyFK7YHw"
headers = {
    "accept": "application/json",
    "x-cg-demo-api-key": api_key
    }

# %%
# Dask Example- Dask Raw Data, Feature Extraction & Selection, and Train-Test Split
# Notes:
# Make sure significant features were found by computing some data from X_train/X_test; 
#   - this code doesnt return an error message like Pandas version
future0= client.submit(My_API_Wraps.CoinGecko_HSPD_Dask, timeframe=timeframe, top_coins=top_coins, periods=periods, api_key=api_key)
future1= client.submit(My_FE_Wraps.EF_Dask, future0, ParameterComplexity=2, LR=True, Vol=False)
future2 = client.submit(My_FS_Wraps.SF_Dask, future1, p_value=0.10)
X, y= future2.result()
X = X.repartition(npartitions=5)
y= y.repartition(npartitions=5)
X_train= X.partitions[0:-1]
X_test= X.partitions[-1]
y_train= y.partitions[0:-1]
y_test= y.partitions[-1]
X_train, X_test, y_train, y_test = client.persist([X_train, X_test, y_train, y_test])
dtrain= dxgb.DaskDMatrix(client, X_train, y_train)
# Out:
# Windows is not officially supported for dask/xgboost, contribution are welcomed.

# %%
X_train.compute()

# %%
# Dask Example:Optuna Hyperparameter Optimization and Model Training
study= My_ML_Wraps.Optuna_XGB_Dask(client, dtrain,  n_trials=500, n_rounds=100, eval_metric= 'mape', tree_method='hist', early_stopping_rounds=20)
final_model= dxgb.train(client, study.best_params, dtrain, num_boost_round=100, evals=[(dtrain, "train")])
model_features = final_model['booster'].feature_names
dtest= dxgb.DaskDMatrix(client, X_test[model_features])
predictions = dxgb.predict(client, final_model, dtest)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# [W 2025-03-02 00:53:04,737] Trial 0 failed with parameters: {'lambda': 3.146874023936724, 'alpha': 1.0911045678813782e-06, 'colsample_bytree': 0.9926989065426313, 'max_depth': 15, 'min_child_weight': 1.2126904536901918e-08, 'learning_rate': 2.187693108700852e-06, 'gamma': 0.0028115301905785573} because of the following error: XGBoostError('[23:53:02] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?\nStack trace:\n  [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]\n  [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]\n  [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]\n  [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]\n  [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]\n  [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]\n  [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]\n  [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]\n  [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]\n\n').
# Traceback (most recent call last):
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\optuna\study\_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "c:\Users\amali\OneDrive\Desktop\Programming\new_programming\My_ML_Wraps.py", line 139, in objective
#     output = dxgb.train(
#              ^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1090, in train
#     return client.sync(
#            ^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 364, in sync
#     return sync(
#            ^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 440, in sync
#     raise error
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 414, in f
#     result = yield future
#              ^^^^^^^^^^^^
#   File "C:\Users\amali\AppData\Roaming\Python\Python312\site-packages\tornado\gen.py", line 767, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1026, in _train_async
#     result = await map_worker_partitions(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 551, in map_worker_partitions
#     result = await client.compute(fut).result()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\client.py", line 410, in _result
#     raise exc.with_traceback(tb)
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 535, in <lambda>
#     lambda *args, **kwargs: [func(*args, **kwargs)],
#     ^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 990, in dispatched_train
#     booster = worker_train(
#     ^^^^^^^^^^^^^^^^^
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 726, in inner_f
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/training.py", line 176, in train
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 179, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 374, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 2743, in num_boosted_rounds
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 284, in _check_call
# xgboost.core.XGBoostError: [23:53:02] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?
# Stack trace:
#   [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]
#   [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]
#   [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]
#   [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]
#   [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]
#   [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]
#   [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]
#   [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]
#   [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]
#
#
# [W 2025-03-02 00:53:04,741] Trial 0 failed with value None.
# [W 2025-03-02 00:53:04,982] Trial 1 failed with parameters: {'lambda': 0.0004200606986444887, 'alpha': 41.53589269457935, 'colsample_bytree': 0.3891976178457907, 'max_depth': 10, 'min_child_weight': 1.3345827742391143e-05, 'learning_rate': 5.465845836899955e-07, 'gamma': 0.05245820774290428} because of the following error: XGBoostError('[23:53:02] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?\nStack trace:\n  [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]\n  [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]\n  [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]\n  [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]\n  [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]\n  [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]\n  [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]\n  [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]\n  [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]\n\n').
# Traceback (most recent call last):
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\optuna\study\_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "c:\Users\amali\OneDrive\Desktop\Programming\new_programming\My_ML_Wraps.py", line 139, in objective
#     output = dxgb.train(
#              ^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1090, in train
#     return client.sync(
#            ^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 364, in sync
#     return sync(
#            ^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 440, in sync
#     raise error
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 414, in f
#     result = yield future
#              ^^^^^^^^^^^^
#   File "C:\Users\amali\AppData\Roaming\Python\Python312\site-packages\tornado\gen.py", line 767, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1026, in _train_async
#     result = await map_worker_partitions(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 551, in map_worker_partitions
#     result = await client.compute(fut).result()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\client.py", line 410, in _result
#     raise exc.with_traceback(tb)
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 535, in <lambda>
#     lambda *args, **kwargs: [func(*args, **kwargs)],
#     ^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 990, in dispatched_train
#     booster = worker_train(
#     ^^^^^^^^^^^^^^^^^
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 726, in inner_f
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/training.py", line 176, in train
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 179, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 374, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 2743, in num_boosted_rounds
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 284, in _check_call
# xgboost.core.XGBoostError: [23:53:02] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?
# Stack trace:
#   [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]
#   [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]
#   [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]
#   [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]
#   [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]
#   [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]
#   [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]
#   [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]
#   [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]
#
#
# [W 2025-03-02 00:53:04,984] Trial 1 failed with value None.
# [W 2025-03-02 00:53:05,219] Trial 3 failed with parameters: {'lambda': 0.5284907274395373, 'alpha': 0.004914624685831245, 'colsample_bytree': 0.9454262570530594, 'max_depth': 19, 'min_child_weight': 26.2602099403552, 'learning_rate': 1.4216291156274137e-05, 'gamma': 0.07115969530236675} because of the following error: XGBoostError('[23:53:02] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?\nStack trace:\n  [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]\n  [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]\n  [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]\n  [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]\n  [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]\n  [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]\n  [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]\n  [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]\n  [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]\n\n').
# Traceback (most recent call last):
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\optuna\study\_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "c:\Users\amali\OneDrive\Desktop\Programming\new_programming\My_ML_Wraps.py", line 139, in objective
#     output = dxgb.train(
#              ^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1090, in train
#     return client.sync(
#            ^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 364, in sync
#     return sync(
#            ^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 440, in sync
#     raise error
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 414, in f
#     result = yield future
#              ^^^^^^^^^^^^
#   File "C:\Users\amali\AppData\Roaming\Python\Python312\site-packages\tornado\gen.py", line 767, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1026, in _train_async
#     result = await map_worker_partitions(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 551, in map_worker_partitions
#     result = await client.compute(fut).result()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\client.py", line 410, in _result
#     raise exc.with_traceback(tb)
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 535, in <lambda>
#     lambda *args, **kwargs: [func(*args, **kwargs)],
#     ^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 990, in dispatched_train
#     booster = worker_train(
#     ^^^^^^^^^^^^^^^^^
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 726, in inner_f
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/training.py", line 176, in train
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 179, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 374, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 2743, in num_boosted_rounds
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 284, in _check_call
# xgboost.core.XGBoostError: [23:53:02] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?
# Stack trace:
#   [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]
#   [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]
#   [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]
#   [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]
#   [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]
#   [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]
#   [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]
#   [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]
#   [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]
#
#
# [W 2025-03-02 00:53:05,220] Trial 3 failed with value None.
# [W 2025-03-02 00:53:05,460] Trial 4 failed with parameters: {'lambda': 2.8069288885021143e-06, 'alpha': 6.732902332029062e-05, 'colsample_bytree': 0.7622258916983113, 'max_depth': 18, 'min_child_weight': 43.55064203460059, 'learning_rate': 0.0003783315928753737, 'gamma': 0.0008803608084767296} because of the following error: XGBoostError('[23:53:03] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?\nStack trace:\n  [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]\n  [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]\n  [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]\n  [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]\n  [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]\n  [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]\n  [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]\n  [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]\n  [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]\n\n').
# Traceback (most recent call last):
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\optuna\study\_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "c:\Users\amali\OneDrive\Desktop\Programming\new_programming\My_ML_Wraps.py", line 139, in objective
#     output = dxgb.train(
#              ^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1090, in train
#     return client.sync(
#            ^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 364, in sync
#     return sync(
#            ^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 440, in sync
#     raise error
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 414, in f
#     result = yield future
#              ^^^^^^^^^^^^
#   File "C:\Users\amali\AppData\Roaming\Python\Python312\site-packages\tornado\gen.py", line 767, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1026, in _train_async
#     result = await map_worker_partitions(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 551, in map_worker_partitions
#     result = await client.compute(fut).result()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\client.py", line 410, in _result
#     raise exc.with_traceback(tb)
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 535, in <lambda>
#     lambda *args, **kwargs: [func(*args, **kwargs)],
#     ^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 990, in dispatched_train
#     booster = worker_train(
#     ^^^^^^^^^^^^^^^^^
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 726, in inner_f
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/training.py", line 176, in train
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 179, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 374, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 2743, in num_boosted_rounds
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 284, in _check_call
# xgboost.core.XGBoostError: [23:53:03] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?
# Stack trace:
#   [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]
#   [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]
#   [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]
#   [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]
#   [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]
#   [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]
#   [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]
#   [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]
#   [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]
#
#
# [W 2025-03-02 00:53:05,461] Trial 4 failed with value None.
# [W 2025-03-02 00:53:05,701] Trial 10 failed with parameters: {'lambda': 0.04025299426687504, 'alpha': 3.492039008011867e-07, 'colsample_bytree': 0.7227659220820668, 'max_depth': 2, 'min_child_weight': 2.0440115938894848e-07, 'learning_rate': 0.0020417568097816146, 'gamma': 1.1113303557539912e-06} because of the following error: XGBoostError('[23:53:03] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?\nStack trace:\n  [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]\n  [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]\n  [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]\n  [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]\n  [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]\n  [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]\n  [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]\n  [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]\n  [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]\n\n').
# Traceback (most recent call last):
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\optuna\study\_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "c:\Users\amali\OneDrive\Desktop\Programming\new_programming\My_ML_Wraps.py", line 139, in objective
#     output = dxgb.train(
#              ^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1090, in train
#     return client.sync(
#            ^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 364, in sync
#     return sync(
#            ^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 440, in sync
#     raise error
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 414, in f
#     result = yield future
#              ^^^^^^^^^^^^
#   File "C:\Users\amali\AppData\Roaming\Python\Python312\site-packages\tornado\gen.py", line 767, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1026, in _train_async
#     result = await map_worker_partitions(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 551, in map_worker_partitions
#     result = await client.compute(fut).result()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\client.py", line 410, in _result
#     raise exc.with_traceback(tb)
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 535, in <lambda>
#     lambda *args, **kwargs: [func(*args, **kwargs)],
#     ^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 990, in dispatched_train
#     booster = worker_train(
#     ^^^^^^^^^^^^^^^^^
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 726, in inner_f
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/training.py", line 176, in train
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 179, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 374, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 2743, in num_boosted_rounds
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 284, in _check_call
# xgboost.core.XGBoostError: [23:53:03] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?
# Stack trace:
#   [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]
#   [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]
#   [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]
#   [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]
#   [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]
#   [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]
#   [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]
#   [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]
#   [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]
#
#
# [W 2025-03-02 00:53:05,704] Trial 10 failed with value None.
# [W 2025-03-02 00:53:05,981] Trial 5 failed with parameters: {'lambda': 32.98294630866299, 'alpha': 88.85333987562154, 'colsample_bytree': 0.3339224388497709, 'max_depth': 19, 'min_child_weight': 0.07051869408559679, 'learning_rate': 5.515714640796904e-06, 'gamma': 2.9166957698443084e-08} because of the following error: XGBoostError('[23:53:03] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?\nStack trace:\n  [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]\n  [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]\n  [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]\n  [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]\n  [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]\n  [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]\n  [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]\n  [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]\n  [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]\n\n').
# Traceback (most recent call last):
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\optuna\study\_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "c:\Users\amali\OneDrive\Desktop\Programming\new_programming\My_ML_Wraps.py", line 139, in objective
#     output = dxgb.train(
#              ^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1090, in train
#     return client.sync(
#            ^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 364, in sync
#     return sync(
#            ^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 440, in sync
#     raise error
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 414, in f
#     result = yield future
#              ^^^^^^^^^^^^
#   File "C:\Users\amali\AppData\Roaming\Python\Python312\site-packages\tornado\gen.py", line 767, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1026, in _train_async
#     result = await map_worker_partitions(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 551, in map_worker_partitions
#     result = await client.compute(fut).result()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\client.py", line 410, in _result
#     raise exc.with_traceback(tb)
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 535, in <lambda>
#     lambda *args, **kwargs: [func(*args, **kwargs)],
#     ^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 990, in dispatched_train
#     booster = worker_train(
#     ^^^^^^^^^^^^^^^^^
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 726, in inner_f
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/training.py", line 176, in train
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 179, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 374, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 2743, in num_boosted_rounds
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 284, in _check_call
# xgboost.core.XGBoostError: [23:53:03] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?
# Stack trace:
#   [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]
#   [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]
#   [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]
#   [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]
#   [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]
#   [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]
#   [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]
#   [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]
#   [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]
#
#
# [W 2025-03-02 00:53:05,984] Trial 5 failed with value None.
# [W 2025-03-02 00:53:06,229] Trial 2 failed with parameters: {'lambda': 2.2835473344481847e-07, 'alpha': 1.3620432784563414e-07, 'colsample_bytree': 0.6132619563625825, 'max_depth': 15, 'min_child_weight': 3.542111137320384e-06, 'learning_rate': 2.4085217102386098e-05, 'gamma': 0.5080434861875956} because of the following error: XGBoostError('[23:53:03] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?\nStack trace:\n  [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]\n  [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]\n  [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]\n  [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]\n  [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]\n  [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]\n  [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]\n  [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]\n  [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]\n\n').
# Traceback (most recent call last):
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\optuna\study\_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "c:\Users\amali\OneDrive\Desktop\Programming\new_programming\My_ML_Wraps.py", line 139, in objective
#     output = dxgb.train(
#              ^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1090, in train
#     return client.sync(
#            ^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 364, in sync
#     return sync(
#            ^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 440, in sync
#     raise error
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 414, in f
#     result = yield future
#              ^^^^^^^^^^^^
#   File "C:\Users\amali\AppData\Roaming\Python\Python312\site-packages\tornado\gen.py", line 767, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1026, in _train_async
#     result = await map_worker_partitions(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 551, in map_worker_partitions
#     result = await client.compute(fut).result()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\client.py", line 410, in _result
#     raise exc.with_traceback(tb)
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 535, in <lambda>
#     lambda *args, **kwargs: [func(*args, **kwargs)],
#     ^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 990, in dispatched_train
#     booster = worker_train(
#     ^^^^^^^^^^^^^^^^^
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 726, in inner_f
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/training.py", line 176, in train
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 179, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 374, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 2743, in num_boosted_rounds
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 284, in _check_call
# xgboost.core.XGBoostError: [23:53:03] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?
# Stack trace:
#   [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]
#   [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]
#   [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]
#   [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]
#   [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]
#   [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]
#   [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]
#   [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]
#   [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]
#
#
# [W 2025-03-02 00:53:06,233] Trial 2 failed with value None.
# [W 2025-03-02 00:53:06,469] Trial 7 failed with parameters: {'lambda': 2.5710494950858777e-05, 'alpha': 0.006656008731791402, 'colsample_bytree': 0.37745131428539413, 'max_depth': 8, 'min_child_weight': 3.2242297965927343e-07, 'learning_rate': 0.012452911907746242, 'gamma': 8.66878875122016e-05} because of the following error: XGBoostError('[23:53:04] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?\nStack trace:\n  [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]\n  [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]\n  [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]\n  [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]\n  [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]\n  [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]\n  [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]\n  [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]\n  [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]\n\n').
# Traceback (most recent call last):
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\optuna\study\_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "c:\Users\amali\OneDrive\Desktop\Programming\new_programming\My_ML_Wraps.py", line 139, in objective
#     output = dxgb.train(
#              ^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1090, in train
#     return client.sync(
#            ^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 364, in sync
#     return sync(
#            ^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 440, in sync
#     raise error
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 414, in f
#     result = yield future
#              ^^^^^^^^^^^^
#   File "C:\Users\amali\AppData\Roaming\Python\Python312\site-packages\tornado\gen.py", line 767, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1026, in _train_async
#     result = await map_worker_partitions(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 551, in map_worker_partitions
#     result = await client.compute(fut).result()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\client.py", line 410, in _result
#     raise exc.with_traceback(tb)
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 535, in <lambda>
#     lambda *args, **kwargs: [func(*args, **kwargs)],
#     ^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 990, in dispatched_train
#     booster = worker_train(
#     ^^^^^^^^^^^^^^^^^
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 726, in inner_f
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/training.py", line 176, in train
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 179, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 374, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 2743, in num_boosted_rounds
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 284, in _check_call
# xgboost.core.XGBoostError: [23:53:04] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?
# Stack trace:
#   [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]
#   [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]
#   [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]
#   [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]
#   [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]
#   [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]
#   [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]
#   [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]
#   [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]
#
#
# [W 2025-03-02 00:53:06,470] Trial 7 failed with value None.
# ...
#     return sync(
#            ^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 440, in sync
#     raise error
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py", line 414, in f
#     result = yield future
#              ^^^^^^^^^^^^
#   File "C:\Users\amali\AppData\Roaming\Python\Python312\site-packages\tornado\gen.py", line 767, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 1026, in _train_async
#     result = await map_worker_partitions(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 551, in map_worker_partitions
#     result = await client.compute(fut).result()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\client.py", line 410, in _result
#     raise exc.with_traceback(tb)
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 535, in <lambda>
#     lambda *args, **kwargs: [func(*args, **kwargs)],
#     ^^^^^^^^^^^^^^^^^
#   File "c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py", line 990, in dispatched_train
#     booster = worker_train(
#     ^^^^^^^^^^^^^^^^^
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 726, in inner_f
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/training.py", line 176, in train
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 179, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py", line 374, in before_training
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 2743, in num_boosted_rounds
#   File "/opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py", line 284, in _check_call
# xgboost.core.XGBoostError: [23:53:07] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?
# Stack trace:
#   [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]
#   [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]
#   [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]
#   [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]
#   [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]
#   [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]
#   [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]
#   [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]
#   [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]
#
#
# [W 2025-03-02 00:53:09,447] Trial 18 failed with value None.
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Dask Example:Optuna Hyperparameter Optimization and Model Training
# ----> 2 study= My_ML_Wraps.Optuna_XGB_Dask(client, dtrain,  n_trials=500, n_rounds=100, eval_metric= 'mape', tree_method='hist', early_stopping_rounds=20)
#       3 final_model= dxgb.train(client, study.best_params, dtrain, num_boost_round=100, evals=[(dtrain, "train")])
#       4 model_features = final_model['booster'].feature_names
#
# File c:\Users\amali\OneDrive\Desktop\Programming\new_programming\My_ML_Wraps.py:152, in Optuna_XGB_Dask(client, dtrain, n_trials, n_rounds, eval_metric, tree_method, parameter_grid, early_stopping_rounds)
#     150 storage = DaskStorage()
#     151 study = optuna.create_study(direction="minimize", storage= storage)
# --> 152 study.optimize(
#     153     objective,
#     154     n_trials=n_trials,
#     155     n_jobs=-1,  # Use all available cores
#     156     gc_after_trial=True,  # Clean memory after each trial
#     157     show_progress_bar=True
#     158     )
#     160 return study
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\optuna\study\study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\optuna\study\_optimize.py:100, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      98                     # Raise if exception occurred in executing the completed futures.
#      99                     for f in completed:
# --> 100                         f.result()
#     102                 futures.add(
#     103                     executor.submit(
#     104                         _optimize_sequential,
#    (...)
#     115                     )
#     116                 )
#     117 finally:
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\optuna\study\_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\optuna\study\_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\optuna\study\_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# File c:\Users\amali\OneDrive\Desktop\Programming\new_programming\My_ML_Wraps.py:139, in Optuna_XGB_Dask.<locals>.objective(trial)
#     136 else:
#     137     param_grid = parameter_grid
# --> 139 output = dxgb.train(
#     140     client,
#     141     param_grid,
#     142     dtrain,
#     143     num_boost_round=n_rounds,
#     144     early_stopping_rounds=early_stopping_rounds,
#     145     evals=[(dtrain, "train")]
#     146 )
#     147 return output["history"]["train"][eval_metric][-1]
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py:1090, in train(client, params, dtrain, num_boost_round, evals, obj, feval, early_stopping_rounds, xgb_model, verbose_eval, callbacks, custom_metric)
#    1088 client = _xgb_get_client(client)
#    1089 args = locals()
# -> 1090 return client.sync(
#    1091     _train_async,
#    1092     global_config=config.get_config(),
#    1093     dconfig=_get_dask_config(),
#    1094     **args,
#    1095 )
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py:364, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     362     return future
#     363 else:
# --> 364     return sync(
#     365         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     366     )
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py:440, in sync(loop, func, callback_timeout, *args, **kwargs)
#     437         wait(10)
#     439 if error is not None:
# --> 440     raise error
#     441 else:
#     442     return result
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\utils.py:414, in sync.<locals>.f()
#     412         awaitable = wait_for(awaitable, timeout)
#     413     future = asyncio.ensure_future(awaitable)
# --> 414     result = yield future
#     415 except Exception as exception:
#     416     error = exception
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tornado\gen.py:767, in Runner.run(self)
#     765 try:
#     766     try:
# --> 767         value = future.result()
#     768     except Exception as e:
#     769         # Save the exception for later. It's important that
#     770         # gen.throw() not be called inside this try/except block
#     771         # because that makes sys.exc_info behave unexpectedly.
#     772         exc: Optional[Exception] = e
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py:1026, in _train_async(client, global_config, dconfig, params, dtrain, num_boost_round, evals, obj, feval, early_stopping_rounds, verbose_eval, xgb_model, callbacks, custom_metric)
#    1023     evals_name = []
#    1024     evals_id = []
# -> 1026 result = await map_worker_partitions(
#    1027     client,
#    1028     dispatched_train,
#    1029     # extra function parameters
#    1030     params,
#    1031     _rabit_args,
#    1032     id(dtrain),
#    1033     evals_name,
#    1034     evals_id,
#    1035     *([dtrain] + evals_data),
#    1036     # workers to be used for training
#    1037     workers=workers,
#    1038 )
#    1039 return result
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py:551, in map_worker_partitions(client, func, workers, *refs)
#     549 bag = db.from_delayed(futures)
#     550 fut = await bag.reduction(first_valid, first_valid)
# --> 551 result = await client.compute(fut).result()
#     553 return result
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\distributed\client.py:410, in Future._result(self, raiseit)
#     408 if raiseit:
#     409     typ, exc, tb = exc
# --> 410     raise exc.with_traceback(tb)
#     411 else:
#     412     return exc
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py:535, in <lambda>()
#     531         else:
#     532             args.append(ref)
#     533     fut = client.submit(
#     534         # turn result into a list for bag construction
# --> 535         lambda *args, **kwargs: [func(*args, **kwargs)],
#     536         *args,
#     537         pure=False,
#     538         workers=[addr],
#     539         allow_other_workers=False,
#     540     )
#     541     futures.append(fut)
#     543 def first_valid(results: Iterable[Optional[_MapRetT]]) -> Optional[_MapRetT]:
#
# File c:\Users\amali\miniconda3\envs\myenvironment\Lib\site-packages\xgboost\dask\__init__.py:990, in dispatched_train()
#     980 with CommunicatorContext(**rabit_args), config.config_context(**global_config):
#     981     Xy, evals = _get_dmatrices(
#     982         train_ref,
#     983         train_id,
#    (...)
#     987         n_threads=n_threads,
#     988     )
# --> 990     booster = worker_train(
#     991         params=local_param,
#     992         dtrain=Xy,
#     993         num_boost_round=num_boost_round,
#     994         evals_result=local_history,
#     995         evals=evals if len(evals) != 0 else None,
#     996         obj=obj,
#     997         feval=feval,
#     998         custom_metric=custom_metric,
#     999         early_stopping_rounds=early_stopping_rounds,
#    1000         verbose_eval=verbose_eval,
#    1001         xgb_model=xgb_model,
#    1002         callbacks=callbacks,
#    1003     )
#    1004 # Don't return the boosters from empty workers. It's quite difficult to
#    1005 # guarantee everything is in sync in the present of empty workers, especially
#    1006 # with complex objectives like quantile.
#    1007 if Xy.num_row() != 0:
#
# File /opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py:726, in inner_f()
#
# File /opt/coiled/env/lib/python3.12/site-packages/xgboost/training.py:176, in train()
#
# File /opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py:179, in before_training()
#
# File /opt/coiled/env/lib/python3.12/site-packages/xgboost/callback.py:374, in before_training()
#
# File /opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py:2743, in num_boosted_rounds()
#
# File /opt/coiled/env/lib/python3.12/site-packages/xgboost/core.py:284, in _check_call()
#
# XGBoostError: [23:53:02] /workspace/src/learner.cc:764: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?
# Stack trace:
#   [bt] (0) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x7f645262dcbc]
#   [bt] (1) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c2820) [0x7f64529c2820]
#   [bt] (2) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(+0x5c93fc) [0x7f64529c93fc]
#   [bt] (3) /opt/coiled/env/lib/python3.12/site-packages/xgboost/lib/libxgboost.so(XGBoosterBoostedRounds+0x34) [0x7f6452535704]
#   [bt] (4) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x6d8a) [0x7f64f4721d8a]
#   [bt] (5) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(+0x61cd) [0x7f64f47211cd]
#   [bt] (6) /opt/coiled/env/lib/python3.12/lib-dynload/../../libffi.so.8(ffi_call+0xcd) [0x7f64f472191d]
#   [bt] (7) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x9854) [0x7f64f4730854]
#   [bt] (8) /opt/coiled/env/lib/python3.12/lib-dynload/_ctypes.cpython-312-x86_64-linux-gnu.so(+0x8bbf) [0x7f64f472fbbf]

# %%
# Dask Example:Final Model Results, Evaluation, & Visualisation
# y_test= y_test.compute()
predictions= pd.Series(predictions.compute(), index=y_test.index)
r2 = r2_score(y_true=y_test, y_pred=predictions)
std = y_test.std()
score = study.best_value
Thresh_var = score/std 
print('Standard_Dev: '+ f'{std}')
print(f"Best parameters: {study.best_params}")
print(f"Best MAPE: {study.best_value}")
print(f"R2 Score: {r2}")
# print(f'Score/Std: {Thresh_var}')
viz = pd.concat([y_test, predictions],axis=1)
viz.columns = ['Actual', 'Predicted']
viz.plot(figsize=(20,10))

# %%
# Pandas Example 1-Pandas with Multiprocessing Distributor: 
# Raw Data, Feature Extraction & Selection, Visualization Results
df_pandas= My_API_Wraps.CoinGecko_HSPD_Pandas(timeframe, top_coins, periods, api_key)
EF_pandas= My_FE_Wraps.EF_Pandas_MultiprocessingDistributor(df_pandas, ParameterComplexity=0)
SF_pandas= My_FS_Wraps.SF_Pandas_v1(EF_pandas)
SF_pandas

# %%
# Pandas Example 1-Pandas with Multiprocessing Distributor: 
# Train-Test Split, XGBoost Hyperparameter Optimization & Model Training, Evaluation, & Visualisation
X= SF_pandas.drop('y_future', axis=1)
y= SF_pandas['y_future']
X_train = X.iloc[:int(-0.2*len(SF_pandas))]
y_train = y.iloc[:int(-0.2*len(SF_pandas))]
X_test = X.iloc[int(-0.2*len(SF_pandas)):]
y_test = y.iloc[int(-0.2*len(SF_pandas)):]
RGS= My_ML_Wraps.RGS_XGB_Pandas(X_train, X_test, y_train, y_test, parameter_grid=None, number_cvs=5)
final_model= RGS.best_estimator_
final_model= final_model.fit(X_train, y_train, eval_set=[(X_train, y_train)])
preds=final_model.predict(X_test)
r2= final_model.score(X_test, y_test)
predictions = pd.DataFrame(preds, columns= ['predicted'], index= X_test.index)
predictions['realised']= y_test.values
predictions.plot(figsize=(20,10))
score = RGS.best_score_
std = y_test.std()
print('RGS Best Score: '+ f'{score}')
print('Y_test Standard_Dev: '+ f'{std}')
print(f'R2: {r2}')
feature_imp = pd.DataFrame(data = final_model.feature_importances_, index= final_model.feature_names_in_, columns=['f_imp']).sort_values(ascending=False, by='f_imp')
Thresh_var = score/std 
print(f'score/std: {Thresh_var}')
display(feature_imp)

# %%
# Pandas Example 2-Pandas with Dask Distributor: 
# Raw Data, Feature Extraction & Selection, Visualization Results
df_pandas2= My_API_Wraps.CoinGecko_HSPD_Pandas(timeframe, top_coins, periods, api_key)
EF_pandas2= My_FE_Wraps.EF_Pandas_DaskDistributor(df_pandas2, cluster.scheduler_address, ParameterComplexity=0)
SF_pandas2= My_FS_Wraps.SF_Pandas_v1(EF_pandas2)
SF_pandas2

# %%
# Pandas Example 2-Pandas with Dask Distributor: 
# Train-Test Split, XGBoost Hyperparameter Optimization & Model Training, Evaluation, & Visualisation
X= SF_pandas2.drop('y_future', axis=1)
y= SF_pandas2['y_future']
X_train = X.iloc[:int(-0.2*len(SF_pandas2))]
y_train = y.iloc[:int(-0.2*len(SF_pandas2))]
X_test = X.iloc[int(-0.2*len(SF_pandas2)):]
y_test = y.iloc[int(-0.2*len(SF_pandas2)):]
RGS= My_ML_Wraps.RGS_XGB_Pandas(X_train, X_test, y_train, y_test, parameter_grid=None, number_cvs=5)
final_model= RGS.best_estimator_
final_model= final_model.fit(X_train, y_train, eval_set=[(X_train, y_train)])
preds=final_model.predict(X_test)
r2= final_model.score(X_test, y_test)
predictions = pd.DataFrame(preds, columns= ['predicted'], index= X_test.index)
predictions['realised']= y_test.values
predictions.plot(figsize=(20,10))
score = RGS.best_score_
std = y_test.std()
print('RGS Best Score: '+ f'{score}')
print('Y_test Standard_Dev: '+ f'{std}')
print(f'R2: {r2}')
feature_imp = pd.DataFrame(data = final_model.feature_importances_, index= final_model.feature_names_in_, columns=['f_imp']).sort_values(ascending=False, by='f_imp')
Thresh_var = score/std 
print(f'score/std: {Thresh_var}')
display(feature_imp)
